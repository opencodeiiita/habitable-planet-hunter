# %%
pip install pandas matplotlib seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os

# List all files inside the 'data' folder
data_folder = "../data"
print("Files in data folder:", os.listdir(data_folder))
# Out:
# Files in data folder: ['full_data.csv']

# %%
import os

# Go to the main folder
main_folder = "C:/Users/91900/Downloads/habitable-planet-hunter-main"
print("Files/folders in main folder:", os.listdir(main_folder))
# Out:
# Files/folders in main folder: ['habitable-planet-hunter-main']

# %%
import os

nested_folder = "C:/Users/91900/Downloads/habitable-planet-hunter-main/habitable-planet-hunter-main"
print("Files/folders inside nested folder:", os.listdir(nested_folder))
# Out:
# Files/folders inside nested folder: ['.gitignore', 'assets', 'Contributing.md', 'data', 'EDA', 'Participants', 'README.md', 'requirements.txt', 'tasks']

# %%
import os

data_folder = "C:/Users/91900/Downloads/habitable-planet-hunter-main/habitable-planet-hunter-main/data"
print("Files in data folder:", os.listdir(data_folder))
# Out:
# Files in data folder: ['full_data.csv']

# %%
import os

print("Current working directory:", os.getcwd())
print("Files/folders here:", os.listdir())
# Out:
# Current working directory: c:\Users\91900\Downloads\habitable-planet-hunter-main\habitable-planet-hunter-main\EDA
# Files/folders here: ['Hac144.ipynb']

# %%
import pandas as pd

# Load dataset with correct relative path
df = pd.read_csv("../data/full_data.csv")

print("Dataset loaded successfully!")
print(df.head())
# Out:
# Dataset loaded successfully!
#        P_NAME  P_STATUS      P_MASS  P_MASS_ERROR_MIN  P_MASS_ERROR_MAX  \
# 0    11 Com b       3.0  6165.86330        -476.74200         476.74200
# 1    11 UMi b       3.0  4684.78480        -794.57001         794.57001
# 2    14 And b       3.0  1525.57440               NaN               NaN
# 3    14 Her b       3.0  1481.07850         -47.67420          47.67420
# 4  16 Cyg B b       3.0   565.73385         -25.42624          25.42624
#
#    P_RADIUS  P_RADIUS_ERROR_MIN  P_RADIUS_ERROR_MAX  P_YEAR   P_UPDATED  ...  \
# 0       NaN                 NaN                 NaN    2007  2014-05-14  ...
# 1       NaN                 NaN                 NaN    2009  2018-09-06  ...
# 2       NaN                 NaN                 NaN    2008  2014-05-14  ...
# 3       NaN                 NaN                 NaN    2002  2018-09-06  ...
# 4       NaN                 NaN                 NaN    1996  2018-09-06  ...
#
# ...

# %%
# Basic info
print("Dataset info:")
print(df.info())

# Summary statistics
print("\nSummary statistics:")
print(df.describe())

# Missing values
print("\nMissing values in each column:")
print(df.isnull().sum())
# Out:
# Dataset info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4048 entries, 0 to 4047
# Columns: 112 entries, P_NAME to P_SEMI_MAJOR_AXIS_EST
# dtypes: float64(94), int64(4), object(14)
# memory usage: 3.5+ MB
# None
#
# Summary statistics:
#        P_STATUS        P_MASS  P_MASS_ERROR_MIN  P_MASS_ERROR_MAX  \
# count    4048.0   1598.000000       1467.000000       1467.000000
# mean        3.0    798.384920       -152.292232        190.289692
# std         0.0   1406.808654        783.366353       1082.061976
# min         3.0      0.019070     -24965.390000          0.000000
# 25%         3.0     26.548968        -79.457001          4.449592
# 50%         3.0    273.332080        -24.154928         25.108412
# 75%         3.0    806.488560         -4.392383         85.813561
# max         3.0  17668.059000          0.270000      26630.808000
#
#           P_RADIUS  P_RADIUS_ERROR_MIN  P_RADIUS_ERROR_MAX       P_YEAR  \
# ...

# %%
import pandas as pd
from sklearn.impute import SimpleImputer
for col in df.columns:
    if df[col].dtype == 'object':
        df[col] = pd.to_numeric(df[col], errors='ignore')
numeric_cols = df.select_dtypes(include='number').columns
print("Numeric columns:", len(numeric_cols))
# Out:
# Numeric columns: 98
# C:\Users\91900\AppData\Local\Temp\ipykernel_4188\1226415542.py:5: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df[col] = pd.to_numeric(df[col], errors='ignore')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Histograms for numeric columns
df[numeric_cols].hist(figsize=(15,12))
plt.suptitle("Numeric Column Distributions")
plt.show()

# %%
plt.figure(figsize=(12,10))
sns.heatmap(df[numeric_cols].corr(), annot=True, fmt=".2f", cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %%
for col in numeric_cols:
    plt.figure(figsize=(8,4))
    sns.boxplot(x=df[col])
    plt.title(f"Boxplot of {col}")
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 3
#       1 for col in numeric_cols:
#       2     plt.figure(figsize=(8,4))
# ----> 3     sns.boxplot(x=df[col])
#       4     plt.title(f"Boxplot of {col}")
#       5     plt.show()
#
# File c:\Users\91900\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:1634, in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, dodge, width, gap, whis, linecolor, linewidth, fliersize, hue_norm, native_scale, log_scale, formatter, legend, ax, **kwargs)
#    1627 color = _default_color(
#    1628     ax.fill_between, hue, color,
#    1629     {k: v for k, v in kwargs.items() if k in ["c", "color", "fc", "facecolor"]},
#    1630     saturation=saturation,
#    1631 )
#    1632 linecolor = p._complement_color(linecolor, color, p._hue_map)
# -> 1634 p.plot_boxes(
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
categorical_cols = df.select_dtypes(include='object').columns

for col in categorical_cols:
    plt.figure(figsize=(8,4))
    sns.countplot(y=df[col], order=df[col].value_counts().index)
    plt.title(f"Countplot of {col}")
    plt.show()
